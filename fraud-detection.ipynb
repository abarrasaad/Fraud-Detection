# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import warnings
warnings.filterwarnings("ignore")
sns.set(style="whitegrid")
pd.set_option('display.float_format', '{:.2f}'.format)

# %%
df = pd.read_csv("AIML Dataset.csv")

# %%
df.shape
# Out:
# (6362620, 11)

# %%
df.head()
# Out:
#    step      type   amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0     1   PAYMENT  9839.64  C1231006815      170136.00       160296.36
# 1     1   PAYMENT  1864.28  C1666544295       21249.00        19384.72
# 2     1  TRANSFER   181.00  C1305486145         181.00            0.00
# 3     1  CASH_OUT   181.00   C840083671         181.00            0.00
# 4     1   PAYMENT 11668.14  C2048537720       41554.00        29885.86
#
#       nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud
# 0  M1979787155            0.00            0.00        0               0
# 1  M2044282225            0.00            0.00        0               0
# 2   C553264065            0.00            0.00        1               0
# 3    C38997010        21182.00            0.00        1               0
# 4  M1230701703            0.00            0.00        0               0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6362620 entries, 0 to 6362619
# Data columns (total 11 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   step            int64
#  1   type            object
#  2   amount          float64
#  3   nameOrig        object
#  4   oldbalanceOrg   float64
#  5   newbalanceOrig  float64
#  6   nameDest        object
#  7   oldbalanceDest  float64
#  8   newbalanceDest  float64
#  9   isFraud         int64
#  10  isFlaggedFraud  int64
# dtypes: float64(5), int64(3), object(3)
# memory usage: 534.0+ MB

# %%
df["isFraud"].value_counts()
# Out:
# isFraud
# 0    6354407
# 1       8213
# Name: count, dtype: int64

# %% [markdown]
# **We have an imbalance of data with only 0.13% being fraud.**

# %%
df["isFlaggedFraud"].value_counts()
# Out:
# isFlaggedFraud
# 0    6362604
# 1         16
# Name: count, dtype: int64

# %% [markdown]
# **It's even lower "isFlaggedFraud" column**

# %%
df.isna().sum()
# Out:
# step              0
# type              0
# amount            0
# nameOrig          0
# oldbalanceOrg     0
# newbalanceOrig    0
# nameDest          0
# oldbalanceDest    0
# newbalanceDest    0
# isFraud           0
# isFlaggedFraud    0
# dtype: int64

# %% [markdown]
# **We have no missing data**

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# **No duplicated rows**

# %%
df["type"].value_counts().plot(kind="bar")
plt.title("Transaction types")
plt.xlabel("Type")
plt.ylabel("Count")
plt.show()

# %%
fraud_by_types = df.groupby(by="type")["isFraud"].mean().sort_values(ascending=False)
fraud_by_types.plot(kind="bar")
plt.title("Fraud rate by type")
plt.xlabel("Type")
plt.ylabel("Fraud rate")
plt.show()

# %%
df["amount"].describe()
# Out:
# count    6362620.00
# mean      179861.90
# std       603858.23
# min            0.00
# 25%        13389.57
# 50%        74871.94
# 75%       208721.48
# max     92445516.64
# Name: amount, dtype: float64

# %%
sns.histplot(np.log1p(df["amount"]), bins=100, kde=True)
plt.title("Transaction Amount Distribution (logged)")
plt.xlabel("Log(amount + 1)")
plt.show()

# %%
sns.boxplot(data = df[df["amount"] < 50000], x="isFraud", y="amount")
plt.title("Amount Filtered By Fraud Rate under 50k")
plt.show()

# %%
df["balanceDiffOrig"] = df["oldbalanceOrg"] - df["newbalanceOrig"]
df["balanceDiffDest"] = df["newbalanceDest"] - df["oldbalanceDest"]

# %%
(df["balanceDiffOrig"] < 0).sum()
# Out:
# np.int64(1399253)

# %%
(df["balanceDiffDest"] < 0).sum()
# Out:
# np.int64(1238864)

# %%
fraud_per_step = df[df["isFraud"] == 1]["step"].value_counts().sort_index()
plt.plot(fraud_per_step.index, fraud_per_step.values, label="Frauds per step")
plt.title("Fraud Over Time")
plt.xlabel("Step (Time)")
plt.ylabel("Number of Frauds")
plt.grid(True)
plt.show()

# %%
df.drop(columns="step", inplace=True)

# %%
df.head()
# Out:
#        type   amount     nameOrig  oldbalanceOrg  newbalanceOrig     nameDest  \
# 0   PAYMENT  9839.64  C1231006815      170136.00       160296.36  M1979787155
# 1   PAYMENT  1864.28  C1666544295       21249.00        19384.72  M2044282225
# 2  TRANSFER   181.00  C1305486145         181.00            0.00   C553264065
# 3  CASH_OUT   181.00   C840083671         181.00            0.00    C38997010
# 4   PAYMENT 11668.14  C2048537720       41554.00        29885.86  M1230701703
#
#    oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud  balanceDiffOrig  \
# 0            0.00            0.00        0               0          9839.64
# 1            0.00            0.00        0               0          1864.28
# 2            0.00            0.00        1               0           181.00
# 3        21182.00            0.00        1               0           181.00
# 4            0.00            0.00        0               0         11668.14
#
#    balanceDiffDest
# 0             0.00
# ...

# %%
top_senders = df["nameOrig"].value_counts().head(10)
top_senders
# Out:
# nameOrig
# C1677795071    3
# C1999539787    3
# C724452879     3
# C1976208114    3
# C400299098     3
# C1784010646    3
# C1530544995    3
# C1065307291    3
# C545315117     3
# C1902386530    3
# Name: count, dtype: int64

# %%
top_receivers = df["nameDest"].value_counts().head(10)
top_receivers
# Out:
# nameDest
# C1286084959    113
# C985934102     109
# C665576141     105
# C2083562754    102
# C248609774     101
# C1590550415    101
# C1789550256     99
# C451111351      99
# C1360767589     98
# C1023714065     97
# Name: count, dtype: int64

# %%
fraud_users = df[df["isFraud"] == 1]["nameOrig"].value_counts().head(10)
fraud_users
# Out:
# nameOrig
# C1305486145    1
# C840083671     1
# C1420196421    1
# C2101527076    1
# C137533655     1
# C1118430673    1
# C749981943     1
# C1334405552    1
# C467632528     1
# C1364127192    1
# Name: count, dtype: int64

# %%
fraud_types = df[df["type"].isin(["TRANSFER", "CASH_OUT"])]
fraud_types.head()
# Out:
#         type    amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 2   TRANSFER    181.00  C1305486145         181.00            0.00
# 3   CASH_OUT    181.00   C840083671         181.00            0.00
# 15  CASH_OUT 229133.94   C905080434       15325.00            0.00
# 19  TRANSFER 215310.30  C1670993182         705.00            0.00
# 24  TRANSFER 311685.89  C1984094095       10835.00            0.00
#
#        nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud  \
# 2    C553264065            0.00            0.00        1               0
# 3     C38997010        21182.00            0.00        1               0
# 15   C476402209         5083.00        51513.44        0               0
# 19  C1100439041        22425.00            0.00        0               0
# 24   C932583850         6267.00      2719172.89        0               0
#
#     balanceDiffOrig  balanceDiffDest
# 2            181.00             0.00
# 3            181.00        -21182.00
# ...

# %%
sns.countplot(data=fraud_types, x="type", hue="isFraud")
plt.title("Fraud Distribution in Transfer & Cashout")
plt.show()

# %%
corr = df[["amount", "oldbalanceOrg", "newbalanceOrig", "oldbalanceDest", "newbalanceDest", "isFraud"]].corr()

# %%
sns.heatmap(corr, annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Matrix")
plt.show()

# %%
zero_after_transfer = df[
    (df["oldbalanceOrg"] > 0) &
    (df["newbalanceOrig"] == 0) &
    (df["type"].isin(["TRANSFER", "CASH_OUT"]))
]

# %%
len(zero_after_transfer)
# Out:
# 1188074

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder

# %%
df.head(2)
# Out:
#       type  amount     nameOrig  oldbalanceOrg  newbalanceOrig     nameDest  \
# 0  PAYMENT 9839.64  C1231006815      170136.00       160296.36  M1979787155
# 1  PAYMENT 1864.28  C1666544295       21249.00        19384.72  M2044282225
#
#    oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud  balanceDiffOrig  \
# 0            0.00            0.00        0               0          9839.64
# 1            0.00            0.00        0               0          1864.28
#
#    balanceDiffDest
# 0             0.00
# 1             0.00

# %%
df_model = df.drop(["nameOrig", "nameDest", "isFlaggedFraud"], axis=1)

# %%
df_model.head()
# Out:
#        type   amount  oldbalanceOrg  newbalanceOrig  oldbalanceDest  \
# 0   PAYMENT  9839.64      170136.00       160296.36            0.00
# 1   PAYMENT  1864.28       21249.00        19384.72            0.00
# 2  TRANSFER   181.00         181.00            0.00            0.00
# 3  CASH_OUT   181.00         181.00            0.00        21182.00
# 4   PAYMENT 11668.14       41554.00        29885.86            0.00
#
#    newbalanceDest  isFraud  balanceDiffOrig  balanceDiffDest
# 0            0.00        0          9839.64             0.00
# 1            0.00        0          1864.28             0.00
# 2            0.00        1           181.00             0.00
# 3            0.00        1           181.00        -21182.00
# 4            0.00        0         11668.14             0.00

# %%
categorical_data = ["type"]
numerical_data = ["amount", "oldbalanceOrg", "newbalanceOrig", "oldbalanceDest", "newbalanceDest"]

# %%
y = df_model["isFraud"]
X = df_model.drop("isFraud", axis=1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, stratify=y)

# %%
preprocessor = ColumnTransformer(
    transformers= [
        ("num", StandardScaler(), numerical_data),
        ("cat", OneHotEncoder(drop="first"), categorical_data)
    ],
    remainder="drop"
)

# %%
pipeline = Pipeline([
    ("prep", preprocessor),
    ("clf", LogisticRegression(class_weight="balanced", max_iter=1000))
])

# %%
pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('prep',
#                  ColumnTransformer(transformers=[('num', StandardScaler(),
#                                                   ['amount', 'oldbalanceOrg',
#                                                    'newbalanceOrig',
#                                                    'oldbalanceDest',
#                                                    'newbalanceDest']),
#                                                  ('cat',
#                                                   OneHotEncoder(drop='first'),
#                                                   ['type'])])),
#                 ('clf',
#                  LogisticRegression(class_weight='balanced', max_iter=1000))])

# %%
y_pred = pipeline.predict(X_test)

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.95      0.97   1906322
#            1       0.02      0.93      0.04      2464
#
#     accuracy                           0.95   1908786
#    macro avg       0.51      0.94      0.51   1908786
# weighted avg       1.00      0.95      0.97   1908786

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[1804051,  102271],
#        [    164,    2300]])

# %%
pipeline.score(X_test, y_test) * 100
# Out:
# 94.63350003614863

# %%
import joblib
joblib.dump(pipeline, "fraud_detection_pipeline.pkl")
# Out:
# ['fraud_detection_pipeline.pkl']
